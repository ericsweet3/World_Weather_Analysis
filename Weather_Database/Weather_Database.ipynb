# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random 
import json

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=64f4e4e35ce7a0a6c940a703fc2f8b1b

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_weather_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_weather_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | anloga
# Processing Record 2 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 1 | tual
# Processing Record 4 of Set 1 | lithgow
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | cap malheureux
# Processing Record 7 of Set 1 | nome
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | dikson
# Processing Record 10 of Set 1 | kalaleh
# Processing Record 11 of Set 1 | daru
# Processing Record 12 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 1 | nouadhibou
# Processing Record 14 of Set 1 | jamestown
# Processing Record 15 of Set 1 | aasiaat
# Processing Record 16 of Set 1 | tvoroyri
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | tooele
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | senekal
# Processing Record 21 of Set 1 | thompson
# Processing Record 22 of Set 1 | port alfred
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | severo-kurilsk
# Processing Record 25 of Set 1 | annau
# Processing Record 26 of Set 1 | avarua
# Processing Record 27 of Set 1 | pevek
# Processing Record 28 of Set 1 | monopoli
# Processing Record 29 of Set 1 | craidorolt
# Processing Record 30 of Set 1 | qui nhon
# Processing Record 31 of Set 1 | erenhot
# Processing Record 32 of Set 1 | capanema
# Processing Record 33 of Set 1 | ciudad bolivar
# Processing Record 34 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 1 | chuy
# Processing Record 36 of Set 1 | narsaq
# Processing Record 37 of Set 1 | miri
# Processing Record 38 of Set 1 | la paz
# Processing Record 39 of Set 1 | bull savanna
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | sechura
# Processing Record 42 of Set 1 | umm lajj
# Processing Record 43 of Set 1 | cidreira
# Processing Record 44 of Set 1 | viseu
# Processing Record 45 of Set 1 | novaya zaimka
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 1 | alihe
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | boende
# Processing Record 1 of Set 2 | hithadhoo
# Processing Record 2 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 2 | el higo
# Processing Record 4 of Set 2 | herat
# Processing Record 5 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | norrtalje
# Processing Record 8 of Set 2 | ribeira grande
# Processing Record 9 of Set 2 | piacabucu
# Processing Record 10 of Set 2 | mendahara
# City not found. Skipping...
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | amreli
# Processing Record 13 of Set 2 | leh
# Processing Record 14 of Set 2 | khatanga
# Processing Record 15 of Set 2 | nanortalik
# Processing Record 16 of Set 2 | ushuaia
# Processing Record 17 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 2 | yulara
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | mayumba
# Processing Record 21 of Set 2 | tuyen quang
# Processing Record 22 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | dubbo
# Processing Record 25 of Set 2 | vaini
# Processing Record 26 of Set 2 | hobart
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | euclides da cunha
# Processing Record 29 of Set 2 | les cayes
# Processing Record 30 of Set 2 | hilo
# Processing Record 31 of Set 2 | baykit
# Processing Record 32 of Set 2 | sioux lookout
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | kaitangata
# Processing Record 35 of Set 2 | atuona
# Processing Record 36 of Set 2 | katsuura
# Processing Record 37 of Set 2 | batemans bay
# Processing Record 38 of Set 2 | yellowknife
# Processing Record 39 of Set 2 | san matias
# Processing Record 40 of Set 2 | kodiak
# Processing Record 41 of Set 2 | hambantota
# Processing Record 42 of Set 2 | los llanos de aridane
# Processing Record 43 of Set 2 | iberia
# Processing Record 44 of Set 2 | codrington
# Processing Record 45 of Set 2 | yumen
# Processing Record 46 of Set 2 | surt
# Processing Record 47 of Set 2 | rafaela
# Processing Record 48 of Set 2 | broken hill
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 2 | tasiilaq
# Processing Record 1 of Set 3 | isangel
# Processing Record 2 of Set 3 | namatanai
# Processing Record 3 of Set 3 | de-kastri
# Processing Record 4 of Set 3 | skjervoy
# Processing Record 5 of Set 3 | batticaloa
# Processing Record 6 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 3 | lazaro cardenas
# Processing Record 8 of Set 3 | fara in sabina
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 3 | prince george
# Processing Record 12 of Set 3 | uruguaiana
# Processing Record 13 of Set 3 | totness
# Processing Record 14 of Set 3 | fort morgan
# Processing Record 15 of Set 3 | berlevag
# Processing Record 16 of Set 3 | treinta y tres
# Processing Record 17 of Set 3 | hermanus
# Processing Record 18 of Set 3 | mitsamiouli
# Processing Record 19 of Set 3 | zhangye
# Processing Record 20 of Set 3 | bluff
# Processing Record 21 of Set 3 | sao filipe
# Processing Record 22 of Set 3 | alvarado
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | klaksvik
# Processing Record 25 of Set 3 | luena
# Processing Record 26 of Set 3 | zhigalovo
# Processing Record 27 of Set 3 | biltine
# Processing Record 28 of Set 3 | kavieng
# Processing Record 29 of Set 3 | mahibadhoo
# Processing Record 30 of Set 3 | cape canaveral
# Processing Record 31 of Set 3 | faanui
# Processing Record 32 of Set 3 | tupik
# Processing Record 33 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 34 of Set 3 | ngunguru
# Processing Record 35 of Set 3 | bethel
# Processing Record 36 of Set 3 | gobabis
# Processing Record 37 of Set 3 | kazerun
# Processing Record 38 of Set 3 | ostrovnoy
# Processing Record 39 of Set 3 | pilar de la horadada
# Processing Record 40 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 3 | inirida
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | lorengau
# Processing Record 44 of Set 3 | kayes
# Processing Record 45 of Set 3 | yenagoa
# Processing Record 46 of Set 3 | mount isa
# Processing Record 47 of Set 3 | black river
# Processing Record 48 of Set 3 | geraldton
# Processing Record 49 of Set 3 | puerto baquerizo moreno
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | takoradi
# Processing Record 2 of Set 4 | karratha
# Processing Record 3 of Set 4 | srednekolymsk
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | bredasdorp
# Processing Record 6 of Set 4 | itarema
# Processing Record 7 of Set 4 | bairiki
# Processing Record 8 of Set 4 | nosy varika
# Processing Record 9 of Set 4 | lulea
# Processing Record 10 of Set 4 | saint anthony
# Processing Record 11 of Set 4 | mar del plata
# Processing Record 12 of Set 4 | grand gaube
# Processing Record 13 of Set 4 | ahuimanu
# Processing Record 14 of Set 4 | mul
# Processing Record 15 of Set 4 | puerto escondido
# Processing Record 16 of Set 4 | russell
# Processing Record 17 of Set 4 | viedma
# Processing Record 18 of Set 4 | vostok
# Processing Record 19 of Set 4 | lamar
# Processing Record 20 of Set 4 | bolton
# Processing Record 21 of Set 4 | barinas
# Processing Record 22 of Set 4 | paralimni
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | arraial do cabo
# Processing Record 25 of Set 4 | kapaa
# Processing Record 26 of Set 4 | fortuna
# Processing Record 27 of Set 4 | poum
# Processing Record 28 of Set 4 | goderich
# Processing Record 29 of Set 4 | fare
# Processing Record 30 of Set 4 | udachnyy
# Processing Record 31 of Set 4 | wang saphung
# Processing Record 32 of Set 4 | saint-philippe
# Processing Record 33 of Set 4 | aviemore
# Processing Record 34 of Set 4 | nara
# Processing Record 35 of Set 4 | cooma
# Processing Record 36 of Set 4 | ponta do sol
# Processing Record 37 of Set 4 | kavaratti
# Processing Record 38 of Set 4 | cabo san lucas
# Processing Record 39 of Set 4 | lompoc
# Processing Record 40 of Set 4 | roros
# Processing Record 41 of Set 4 | marsh harbour
# Processing Record 42 of Set 4 | yefimovskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | nizhneangarsk
# Processing Record 44 of Set 4 | souillac
# Processing Record 45 of Set 4 | labuhan
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 48 of Set 4 | tuatapere
# Processing Record 49 of Set 4 | porto novo
# Processing Record 50 of Set 4 | masterton
# Processing Record 1 of Set 5 | castro
# Processing Record 2 of Set 5 | fort-shevchenko
# Processing Record 3 of Set 5 | kupang
# Processing Record 4 of Set 5 | camrose
# Processing Record 5 of Set 5 | bitung
# Processing Record 6 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 5 | nagutskoye
# Processing Record 8 of Set 5 | yuzawa
# Processing Record 9 of Set 5 | gameleira
# Processing Record 10 of Set 5 | nikolskoye
# Processing Record 11 of Set 5 | tiquicheo
# Processing Record 12 of Set 5 | puerto colombia
# Processing Record 13 of Set 5 | saint-augustin
# Processing Record 14 of Set 5 | lincoln
# Processing Record 15 of Set 5 | tabou
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | beringovskiy
# Processing Record 18 of Set 5 | jalu
# Processing Record 19 of Set 5 | djambala
# Processing Record 20 of Set 5 | saldanha
# Processing Record 21 of Set 5 | pimenta bueno
# Processing Record 22 of Set 5 | roswell
# Processing Record 23 of Set 5 | namibe
# Processing Record 24 of Set 5 | gola gokarannath
# Processing Record 25 of Set 5 | flinders
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | mackay
# Processing Record 28 of Set 5 | tuktoyaktuk
# Processing Record 29 of Set 5 | esqueda
# Processing Record 30 of Set 5 | lar
# Processing Record 31 of Set 5 | warwick
# Processing Record 32 of Set 5 | nhulunbuy
# Processing Record 33 of Set 5 | buin
# Processing Record 34 of Set 5 | behbahan
# Processing Record 35 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 5 | sambava
# Processing Record 37 of Set 5 | bambous virieux
# Processing Record 38 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 5 | kassala
# Processing Record 40 of Set 5 | qinhuangdao
# Processing Record 41 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 42 of Set 5 | belyy yar
# Processing Record 43 of Set 5 | bandarbeyla
# Processing Record 44 of Set 5 | monrovia
# Processing Record 45 of Set 5 | san patricio
# Processing Record 46 of Set 5 | outram
# Processing Record 47 of Set 5 | pemangkat
# Processing Record 48 of Set 5 | babanusah
# City not found. Skipping...
# Processing Record 49 of Set 5 | sisimiut
# Processing Record 50 of Set 5 | hualmay
# Processing Record 1 of Set 6 | bongandanga
# Processing Record 2 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 6 | kapit
# Processing Record 5 of Set 6 | leninsk
# Processing Record 6 of Set 6 | prince rupert
# Processing Record 7 of Set 6 | fairbanks
# Processing Record 8 of Set 6 | tibati
# Processing Record 9 of Set 6 | opuwo
# Processing Record 10 of Set 6 | vila franca do campo
# Processing Record 11 of Set 6 | yar-sale
# Processing Record 12 of Set 6 | fort nelson
# Processing Record 13 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 14 of Set 6 | cherskiy
# Processing Record 15 of Set 6 | byron bay
# Processing Record 16 of Set 6 | mayor pablo lagerenza
# Processing Record 17 of Set 6 | san andres
# Processing Record 18 of Set 6 | chingirlau
# Processing Record 19 of Set 6 | sibu
# Processing Record 20 of Set 6 | zaozerne
# Processing Record 21 of Set 6 | versalles
# Processing Record 22 of Set 6 | paamiut
# Processing Record 23 of Set 6 | verkhnetulomskiy
# Processing Record 24 of Set 6 | mecca
# Processing Record 25 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 6 | kommunar
# Processing Record 27 of Set 6 | zhadovka
# Processing Record 28 of Set 6 | balabac
# Processing Record 29 of Set 6 | buariki
# City not found. Skipping...
# Processing Record 30 of Set 6 | tiarei
# Processing Record 31 of Set 6 | norman wells
# Processing Record 32 of Set 6 | te anau
# Processing Record 33 of Set 6 | port macquarie
# Processing Record 34 of Set 6 | sabang
# Processing Record 35 of Set 6 | antofagasta
# Processing Record 36 of Set 6 | ucluelet
# Processing Record 37 of Set 6 | hobyo
# Processing Record 38 of Set 6 | chicama
# Processing Record 39 of Set 6 | anan
# Processing Record 40 of Set 6 | altonia
# City not found. Skipping...
# Processing Record 41 of Set 6 | muisne
# Processing Record 42 of Set 6 | san vicente
# Processing Record 43 of Set 6 | santa maria
# Processing Record 44 of Set 6 | iqaluit
# Processing Record 45 of Set 6 | strathpeffer
# Processing Record 46 of Set 6 | naftah
# City not found. Skipping...
# Processing Record 47 of Set 6 | tandil
# Processing Record 48 of Set 6 | luderitz
# Processing Record 49 of Set 6 | shadrinsk
# Processing Record 50 of Set 6 | bathurst
# Processing Record 1 of Set 7 | aripuana
# Processing Record 2 of Set 7 | mehamn
# Processing Record 3 of Set 7 | havoysund
# Processing Record 4 of Set 7 | palmer
# Processing Record 5 of Set 7 | port hardy
# Processing Record 6 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 7 of Set 7 | harbour breton
# Processing Record 8 of Set 7 | port jervis
# Processing Record 9 of Set 7 | ust-kuyga
# Processing Record 10 of Set 7 | holme
# Processing Record 11 of Set 7 | eureka
# Processing Record 12 of Set 7 | kudahuvadhoo
# Processing Record 13 of Set 7 | akyab
# Processing Record 14 of Set 7 | kolodeznyy
# Processing Record 15 of Set 7 | tiaong
# Processing Record 16 of Set 7 | tselinnoye
# Processing Record 17 of Set 7 | yining
# Processing Record 18 of Set 7 | clyde river
# Processing Record 19 of Set 7 | camana
# Processing Record 20 of Set 7 | torbay
# Processing Record 21 of Set 7 | necochea
# Processing Record 22 of Set 7 | tiksi
# Processing Record 23 of Set 7 | leningradskiy
# Processing Record 24 of Set 7 | gat
# Processing Record 25 of Set 7 | paracatu
# Processing Record 26 of Set 7 | camopi
# Processing Record 27 of Set 7 | canutama
# Processing Record 28 of Set 7 | macas
# Processing Record 29 of Set 7 | port lincoln
# Processing Record 30 of Set 7 | xining
# Processing Record 31 of Set 7 | the valley
# Processing Record 32 of Set 7 | new norfolk
# Processing Record 33 of Set 7 | batagay
# Processing Record 34 of Set 7 | port elizabeth
# Processing Record 35 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 7 | taltal
# Processing Record 37 of Set 7 | saint george
# Processing Record 38 of Set 7 | pafos
# Processing Record 39 of Set 7 | bonthe
# Processing Record 40 of Set 7 | lata
# Processing Record 41 of Set 7 | himora
# City not found. Skipping...
# Processing Record 42 of Set 7 | acajutla
# Processing Record 43 of Set 7 | korla
# Processing Record 44 of Set 7 | cabedelo
# Processing Record 45 of Set 7 | jasper
# Processing Record 46 of Set 7 | derbent
# Processing Record 47 of Set 7 | otjiwarongo
# Processing Record 48 of Set 7 | carnarvon
# Processing Record 49 of Set 7 | pangnirtung
# Processing Record 50 of Set 7 | rosetta
# Processing Record 1 of Set 8 | charcas
# Processing Record 2 of Set 8 | kilindoni
# Processing Record 3 of Set 8 | goedereede
# Processing Record 4 of Set 8 | vestmannaeyjar
# Processing Record 5 of Set 8 | nishihara
# Processing Record 6 of Set 8 | mocuba
# Processing Record 7 of Set 8 | zacatecas
# Processing Record 8 of Set 8 | komsomolskiy
# Processing Record 9 of Set 8 | kuah
# Processing Record 10 of Set 8 | ambon
# Processing Record 11 of Set 8 | poro
# Processing Record 12 of Set 8 | saskylakh
# Processing Record 13 of Set 8 | kapustin yar-1
# City not found. Skipping...
# Processing Record 14 of Set 8 | makakilo city
# Processing Record 15 of Set 8 | upernavik
# Processing Record 16 of Set 8 | altagracia de orituco
# Processing Record 17 of Set 8 | pisco
# Processing Record 18 of Set 8 | ternate
# Processing Record 19 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 20 of Set 8 | bontang
# Processing Record 21 of Set 8 | caravelas
# Processing Record 22 of Set 8 | hami
# Processing Record 23 of Set 8 | visnes
# Processing Record 24 of Set 8 | miraflores
# Processing Record 25 of Set 8 | ishigaki
# Processing Record 26 of Set 8 | dingzhou
# Processing Record 27 of Set 8 | husavik
# Processing Record 28 of Set 8 | neiafu
# Processing Record 29 of Set 8 | honningsvag
# Processing Record 30 of Set 8 | alpatovo
# Processing Record 31 of Set 8 | half moon bay
# Processing Record 32 of Set 8 | guerrero negro
# Processing Record 33 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 8 | les escoumins
# Processing Record 35 of Set 8 | sur
# Processing Record 36 of Set 8 | lac du bonnet
# Processing Record 37 of Set 8 | dunmore town
# Processing Record 38 of Set 8 | college
# Processing Record 39 of Set 8 | okha
# Processing Record 40 of Set 8 | telde
# Processing Record 41 of Set 8 | oktyabrskiy
# Processing Record 42 of Set 8 | basco
# Processing Record 43 of Set 8 | tambura
# Processing Record 44 of Set 8 | fujisawa
# Processing Record 45 of Set 8 | paris
# Processing Record 46 of Set 8 | kumano
# Processing Record 47 of Set 8 | hole narsipur
# Processing Record 48 of Set 8 | port maria
# Processing Record 49 of Set 8 | katobu
# Processing Record 50 of Set 8 | aklavik
# Processing Record 1 of Set 9 | riyadh
# Processing Record 2 of Set 9 | coracora
# Processing Record 3 of Set 9 | yerbogachen
# Processing Record 4 of Set 9 | broome
# Processing Record 5 of Set 9 | sept-iles
# Processing Record 6 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 9 | gajendragarh
# Processing Record 8 of Set 9 | kenai
# Processing Record 9 of Set 9 | hasaki
# Processing Record 10 of Set 9 | vogan
# Processing Record 11 of Set 9 | plainfield
# Processing Record 12 of Set 9 | aliwal north
# Processing Record 13 of Set 9 | emerald
# Processing Record 14 of Set 9 | lodja
# Processing Record 15 of Set 9 | kristiansund
# Processing Record 16 of Set 9 | sabha
# Processing Record 17 of Set 9 | brae
# Processing Record 18 of Set 9 | la libertad
# Processing Record 19 of Set 9 | bukachacha
# Processing Record 20 of Set 9 | banjar
# Processing Record 21 of Set 9 | meulaboh
# Processing Record 22 of Set 9 | vicuna
# Processing Record 23 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 24 of Set 9 | mogwase
# Processing Record 25 of Set 9 | innisfail
# Processing Record 26 of Set 9 | marawi
# Processing Record 27 of Set 9 | wanning
# Processing Record 28 of Set 9 | kharan
# Processing Record 29 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 9 | plettenberg bay
# Processing Record 31 of Set 9 | misratah
# Processing Record 32 of Set 9 | talcahuano
# Processing Record 33 of Set 9 | dabwali
# Processing Record 34 of Set 9 | tamiahua
# Processing Record 35 of Set 9 | emborion
# Processing Record 36 of Set 9 | port blair
# Processing Record 37 of Set 9 | uk
# City not found. Skipping...
# Processing Record 38 of Set 9 | tchibanga
# Processing Record 39 of Set 9 | eldorado
# Processing Record 40 of Set 9 | shillong
# Processing Record 41 of Set 9 | terme
# Processing Record 42 of Set 9 | mahebourg
# Processing Record 43 of Set 9 | nieuw amsterdam
# Processing Record 44 of Set 9 | simpang
# Processing Record 45 of Set 9 | crailsheim
# Processing Record 46 of Set 9 | utiel
# Processing Record 47 of Set 9 | nemuro
# Processing Record 48 of Set 9 | atkarsk
# Processing Record 49 of Set 9 | nuuk
# Processing Record 50 of Set 9 | quatre cocos
# Processing Record 1 of Set 10 | deputatskiy
# Processing Record 2 of Set 10 | muros
# Processing Record 3 of Set 10 | talnakh
# Processing Record 4 of Set 10 | riberalta
# Processing Record 5 of Set 10 | sao sebastiao
# Processing Record 6 of Set 10 | salvador
# Processing Record 7 of Set 10 | alpena
# Processing Record 8 of Set 10 | gorin
# Processing Record 9 of Set 10 | tabarqah
# City not found. Skipping...
# Processing Record 10 of Set 10 | likasi
# Processing Record 11 of Set 10 | varkaus
# Processing Record 12 of Set 10 | dongsheng
# Processing Record 13 of Set 10 | portland
# Processing Record 14 of Set 10 | aden
# Processing Record 15 of Set 10 | babati
# Processing Record 16 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 10 | costa rica
# Processing Record 18 of Set 10 | dillon
# Processing Record 19 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 20 of Set 10 | lakselv
# Processing Record 21 of Set 10 | olinda
# Processing Record 22 of Set 10 | shakiso
# Processing Record 23 of Set 10 | along
# Processing Record 24 of Set 10 | guanica
# Processing Record 25 of Set 10 | peleduy
# Processing Record 26 of Set 10 | imbituba
# Processing Record 27 of Set 10 | bathsheba
# Processing Record 28 of Set 10 | asosa
# Processing Record 29 of Set 10 | balatonfoldvar
# Processing Record 30 of Set 10 | zalesovo
# Processing Record 31 of Set 10 | susanville
# Processing Record 32 of Set 10 | san cristobal
# Processing Record 33 of Set 10 | popondetta
# Processing Record 34 of Set 10 | jiancheng
# Processing Record 35 of Set 10 | la ronge
# Processing Record 36 of Set 10 | dwarka
# Processing Record 37 of Set 10 | hata
# Processing Record 38 of Set 10 | buala
# Processing Record 39 of Set 10 | bengkulu
# Processing Record 40 of Set 10 | seoul
# Processing Record 41 of Set 10 | vardo
# Processing Record 42 of Set 10 | padang
# Processing Record 43 of Set 10 | saurimo
# Processing Record 44 of Set 10 | alofi
# Processing Record 45 of Set 10 | nantucket
# Processing Record 46 of Set 10 | laibin
# Processing Record 47 of Set 10 | yuncheng
# Processing Record 48 of Set 10 | rocky mountain house
# Processing Record 49 of Set 10 | bishop auckland
# Processing Record 50 of Set 10 | temiscaming
# Processing Record 1 of Set 11 | tombouctou
# Processing Record 2 of Set 11 | soyo
# Processing Record 3 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 11 | waipawa
# Processing Record 5 of Set 11 | oranjestad
# Processing Record 6 of Set 11 | comodoro rivadavia
# Processing Record 7 of Set 11 | natal
# Processing Record 8 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 9 of Set 11 | xiangdong
# City not found. Skipping...
# Processing Record 10 of Set 11 | montbrison
# Processing Record 11 of Set 11 | gravenhurst
# Processing Record 12 of Set 11 | jhabua
# Processing Record 13 of Set 11 | bonavista
# Processing Record 14 of Set 11 | longyearbyen
# Processing Record 15 of Set 11 | trelew
# Processing Record 16 of Set 11 | manakara
# Processing Record 17 of Set 11 | sikasso
# Processing Record 18 of Set 11 | hayden
# Processing Record 19 of Set 11 | shumyachi
# Processing Record 20 of Set 11 | smithers
# Processing Record 21 of Set 11 | jiroft
# City not found. Skipping...
# Processing Record 22 of Set 11 | uchiza
# Processing Record 23 of Set 11 | constitucion
# Processing Record 24 of Set 11 | grootegast
# Processing Record 25 of Set 11 | maceio
# Processing Record 26 of Set 11 | penzance
# Processing Record 27 of Set 11 | tura
# Processing Record 28 of Set 11 | svetlogorsk
# Processing Record 29 of Set 11 | andenes
# Processing Record 30 of Set 11 | mokrousovo
# Processing Record 31 of Set 11 | oistins
# Processing Record 32 of Set 11 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 11 | bogorodskoye
# Processing Record 34 of Set 11 | sinnamary
# Processing Record 35 of Set 11 | shingu
# Processing Record 36 of Set 11 | bambanglipuro
# Processing Record 37 of Set 11 | libertador general san martin
# Processing Record 38 of Set 11 | pa sang
# Processing Record 39 of Set 11 | odessa
# Processing Record 40 of Set 11 | harper
# Processing Record 41 of Set 11 | mount gambier
# Processing Record 42 of Set 11 | navolato
# Processing Record 43 of Set 11 | poya
# Processing Record 44 of Set 11 | slovenska bistrica
# Processing Record 45 of Set 11 | ajdabiya
# Processing Record 46 of Set 11 | payo
# Processing Record 47 of Set 11 | dukat
# Processing Record 48 of Set 11 | ahipara
# Processing Record 49 of Set 11 | saint-pierre
# Processing Record 50 of Set 11 | san jose
# Processing Record 1 of Set 12 | kirakira
# Processing Record 2 of Set 12 | aguimes
# Processing Record 3 of Set 12 | springbok
# Processing Record 4 of Set 12 | nigran
# Processing Record 5 of Set 12 | omboue
# Processing Record 6 of Set 12 | chaplynka
# Processing Record 7 of Set 12 | sonari
# Processing Record 8 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 12 | mareeba
# Processing Record 10 of Set 12 | kieta
# Processing Record 11 of Set 12 | rosarito
# Processing Record 12 of Set 12 | khovu-aksy
# Processing Record 13 of Set 12 | omsukchan
# Processing Record 14 of Set 12 | lavrentiya
# Processing Record 15 of Set 12 | japura
# Processing Record 16 of Set 12 | natalio
# Processing Record 17 of Set 12 | touros
# Processing Record 18 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 12 | praxedis guerrero
# Processing Record 20 of Set 12 | sahrak
# City not found. Skipping...
# Processing Record 21 of Set 12 | porto walter
# Processing Record 22 of Set 12 | gizo
# Processing Record 23 of Set 12 | spas-klepiki
# Processing Record 24 of Set 12 | oschatz
# Processing Record 25 of Set 12 | villazon
# Processing Record 26 of Set 12 | san pedro
# Processing Record 27 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 28 of Set 12 | nevel
# Processing Record 29 of Set 12 | ostersund
# Processing Record 30 of Set 12 | adrar
# Processing Record 31 of Set 12 | alta floresta
# Processing Record 32 of Set 12 | colares
# Processing Record 33 of Set 12 | atikokan
# Processing Record 34 of Set 12 | araguacu
# Processing Record 35 of Set 12 | sao geraldo do araguaia
# Processing Record 36 of Set 12 | sangar
# Processing Record 37 of Set 12 | tieling
# Processing Record 38 of Set 12 | dzerzhinsk
# Processing Record 39 of Set 12 | north bend
# Processing Record 40 of Set 12 | cururupu
# Processing Record 41 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 42 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 43 of Set 12 | fairmont
# Processing Record 44 of Set 12 | lanzhou
# Processing Record 45 of Set 12 | huaihua
# Processing Record 46 of Set 12 | shimoda
# Processing Record 47 of Set 12 | luebo
# Processing Record 48 of Set 12 | grand baie
# Processing Record 49 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 12 | kanigiri
# Processing Record 1 of Set 13 | bronnoysund
# Processing Record 2 of Set 13 | kananga
# Processing Record 3 of Set 13 | tuy hoa
# Processing Record 4 of Set 13 | devils lake
# Processing Record 5 of Set 13 | gazanjyk
# Processing Record 6 of Set 13 | west bay
# Processing Record 7 of Set 13 | esperance
# Processing Record 8 of Set 13 | cumberland
# Processing Record 9 of Set 13 | waingapu
# Processing Record 10 of Set 13 | ardakan
# Processing Record 11 of Set 13 | jamay
# Processing Record 12 of Set 13 | alyangula
# Processing Record 13 of Set 13 | camargo
# Processing Record 14 of Set 13 | olafsvik
# Processing Record 15 of Set 13 | angoche
# Processing Record 16 of Set 13 | havelian
# Processing Record 17 of Set 13 | muzaffarabad
# Processing Record 18 of Set 13 | urumqi
# Processing Record 19 of Set 13 | westport
# Processing Record 20 of Set 13 | pacific grove
# Processing Record 21 of Set 13 | curuca
# Processing Record 22 of Set 13 | praia
# Processing Record 23 of Set 13 | yavatmal
# Processing Record 24 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 25 of Set 13 | goma
# Processing Record 26 of Set 13 | staryy nadym
# Processing Record 27 of Set 13 | ossora
# Processing Record 28 of Set 13 | khandbari
# Processing Record 29 of Set 13 | riverton
# Processing Record 30 of Set 13 | ipixuna
# Processing Record 31 of Set 13 | catuday
# Processing Record 32 of Set 13 | atasu
# Processing Record 33 of Set 13 | abbeville
# Processing Record 34 of Set 13 | auki
# Processing Record 35 of Set 13 | perrenjas
# City not found. Skipping...
# Processing Record 36 of Set 13 | tapes
# Processing Record 37 of Set 13 | sarankhola
# Processing Record 38 of Set 13 | arkhipo-osipovka
# Processing Record 39 of Set 13 | energeticheskiy
# Processing Record 40 of Set 13 | conceicao do araguaia
# Processing Record 41 of Set 13 | coihueco
# Processing Record 42 of Set 13 | tigil
# Processing Record 43 of Set 13 | noshiro
# Processing Record 44 of Set 13 | kati
# Processing Record 45 of Set 13 | cayenne
# Processing Record 46 of Set 13 | egvekinot
# Processing Record 47 of Set 13 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 13 | caucaia
# Processing Record 49 of Set 13 | le port
# Processing Record 50 of Set 13 | gayeri
# Processing Record 1 of Set 14 | kysyl-syr
# Processing Record 2 of Set 14 | sibolga
# Processing Record 3 of Set 14 | naze
# Processing Record 4 of Set 14 | ordzhonikidze
# Processing Record 5 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 6 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 14 | esna
# Processing Record 8 of Set 14 | lasa
# Processing Record 9 of Set 14 | zhigansk
# Processing Record 10 of Set 14 | huarmey
# Processing Record 11 of Set 14 | wajid
# Processing Record 12 of Set 14 | bilibino
# Processing Record 13 of Set 14 | san quintin
# Processing Record 14 of Set 14 | matadi
# Processing Record 15 of Set 14 | hofn
# Processing Record 16 of Set 14 | eyemouth
# Processing Record 17 of Set 14 | sao joao da barra
# Processing Record 18 of Set 14 | alvaraes
# Processing Record 19 of Set 14 | morondava
# Processing Record 20 of Set 14 | santo tomas
# Processing Record 21 of Set 14 | havre-saint-pierre
# Processing Record 22 of Set 14 | milford
# Processing Record 23 of Set 14 | cockburn town
# Processing Record 24 of Set 14 | xichang
# Processing Record 25 of Set 14 | thunder bay
# Processing Record 26 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 14 | churapcha
# Processing Record 28 of Set 14 | ixtapa
# Processing Record 29 of Set 14 | salinas
# Processing Record 30 of Set 14 | aykhal
# Processing Record 31 of Set 14 | guiuan
# Processing Record 32 of Set 14 | ampanihy
# Processing Record 33 of Set 14 | hailar
# Processing Record 34 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 14 | pangkalanbuun
# Processing Record 36 of Set 14 | olovo
# Processing Record 37 of Set 14 | pasan
# Processing Record 38 of Set 14 | asau
# Processing Record 39 of Set 14 | manta
# Processing Record 40 of Set 14 | atar
# Processing Record 41 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 14 | ondjiva
# Processing Record 43 of Set 14 | grafton
# Processing Record 44 of Set 14 | kathu
# Processing Record 45 of Set 14 | general pico
# Processing Record 46 of Set 14 | santa marta
# Processing Record 47 of Set 14 | magistralnyy
# Processing Record 48 of Set 14 | palana
# Processing Record 49 of Set 14 | maarianhamina
# Processing Record 50 of Set 14 | kurilsk
# Processing Record 1 of Set 15 | mnogovershinnyy
# Processing Record 2 of Set 15 | telford
# Processing Record 3 of Set 15 | dingle
# Processing Record 4 of Set 15 | hoquiam
# Processing Record 5 of Set 15 | vao
# Processing Record 6 of Set 15 | maputo
# Processing Record 7 of Set 15 | vilhena
# Processing Record 8 of Set 15 | rio gallegos
# Processing Record 9 of Set 15 | ancud
# Processing Record 10 of Set 15 | oranjemund
# Processing Record 11 of Set 15 | praia da vitoria
# Processing Record 12 of Set 15 | nioro
# Processing Record 13 of Set 15 | ballina
# Processing Record 14 of Set 15 | edson
# Processing Record 15 of Set 15 | ijaki
# City not found. Skipping...
# Processing Record 16 of Set 15 | ambanja
# Processing Record 17 of Set 15 | kuusamo
# Processing Record 18 of Set 15 | puerto pailas
# Processing Record 19 of Set 15 | tukrah
# Processing Record 20 of Set 15 | takatsuki
# Processing Record 21 of Set 15 | aginskoye
# Processing Record 22 of Set 15 | san lorenzo
# Processing Record 23 of Set 15 | januaria
# Processing Record 24 of Set 15 | price
# Processing Record 25 of Set 15 | rock sound
# Processing Record 26 of Set 15 | kargasok
# Processing Record 27 of Set 15 | hamilton
# Processing Record 28 of Set 15 | mitzic
# Processing Record 29 of Set 15 | mandalgovi
# Processing Record 30 of Set 15 | huanta
# Processing Record 31 of Set 15 | bagan
# Processing Record 32 of Set 15 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 33 of Set 15 | eyl
# Processing Record 34 of Set 15 | liapades
# City not found. Skipping...
# Processing Record 35 of Set 15 | abu dhabi
# Processing Record 36 of Set 15 | puro
# Processing Record 37 of Set 15 | providencia
# Processing Record 38 of Set 15 | chulman
# Processing Record 39 of Set 15 | yarada
# Processing Record 40 of Set 15 | bhawanipatna
# Processing Record 41 of Set 15 | luang prabang
# Processing Record 42 of Set 15 | kamenka
# Processing Record 43 of Set 15 | dharchula
# Processing Record 44 of Set 15 | macau
# Processing Record 45 of Set 15 | amazar
# Processing Record 46 of Set 15 | apodi
# Processing Record 47 of Set 15 | taywarah
# Processing Record 48 of Set 15 | tabuk
# Processing Record 49 of Set 15 | usinsk
# Processing Record 50 of Set 15 | santa cruz
# Processing Record 1 of Set 16 | kokoda
# Processing Record 2 of Set 16 | constancia
# Processing Record 3 of Set 16 | belmonte
# Processing Record 4 of Set 16 | fameck
# Processing Record 5 of Set 16 | maningrida
# Processing Record 6 of Set 16 | lebanon
# Processing Record 7 of Set 16 | hirara
# Processing Record 8 of Set 16 | trairi
# Processing Record 9 of Set 16 | yatou
# Processing Record 10 of Set 16 | bay roberts
# Processing Record 11 of Set 16 | moranbah
# Processing Record 12 of Set 16 | bodo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Anloga      GH   5.7947    0.8973     87.80        70          20
# 1            Tual      ID  -5.6667  132.7500     83.28        75         100
# 2         Lithgow      AU -33.4833  150.1500     62.01        43         100
# 3       Busselton      AU -33.6500  115.3333     64.00        80           0
# 4  Cap Malheureux      MU -19.9842   57.6142     81.00        78           2
# 5            Nome      US  64.5011 -165.4064      1.40        71          40
# 6          Dikson      RU  73.5069   80.5464    -33.18        84          54
# 7         Kalaleh      IR  37.3807   55.4916     55.40        50           0
# 8            Daru      PG  -9.0763  143.2092     77.95        88          99
# 9      Nouadhibou      MR  20.9310  -17.0347     87.80        20           0
#
#    Wind Speed Current Description                 Date
# 0       11.50          few clouds  2021-01-29 17:00:16
# 1       17.83     overcast clouds  2021-01-29 16:56:21
# 2        3.09     overcast clouds  2021-01-29 17:00:16
# 3        1.99           clear sky  2021-01-29 17:00:17
# 4        5.01           clear sky  2021-01-29 17:00:17
# 5        3.44    scattered clouds  2021-01-29 16:59:53
# 6        4.88       broken clouds  2021-01-29 17:00:17
# 7        7.54           clear sky  2021-01-29 17:00:17
# 8       14.23       moderate rain  2021-01-29 17:00:18
# 9       12.66           clear sky  2021-01-29 17:00:18

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
new_column_order = city_data_df
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Anloga      GH   5.7947    0.8973     87.80        70
# 1              Tual      ID  -5.6667  132.7500     83.28        75
# 2           Lithgow      AU -33.4833  150.1500     62.01        43
# 3         Busselton      AU -33.6500  115.3333     64.00        80
# 4    Cap Malheureux      MU -19.9842   57.6142     81.00        78
# ..              ...     ...      ...       ...       ...       ...
# 692          Trairi      BR  -3.2778  -39.2689     86.32        61
# 693           Yatou      CN  37.1500  122.3833     36.86        81
# 694     Bay Roberts      CA  47.5999  -53.2648     28.00        80
# 695        Moranbah      AU -22.0016  148.0466     68.04        90
# 696            Bodo      NO  67.2800   14.4050     19.00        57
#
#      Cloudiness  Wind Speed Current Description                 Date
# 0            20       11.50          few clouds  2021-01-29 17:00:16
# 1           100       17.83     overcast clouds  2021-01-29 16:56:21
# 2           100        3.09     overcast clouds  2021-01-29 17:00:16
# 3             0        1.99           clear sky  2021-01-29 17:00:17
# 4             2        5.01           clear sky  2021-01-29 17:00:17
# ..          ...         ...                 ...                  ...
# 692          95       12.95          light rain  2021-01-29 17:02:12
# 693           0       15.97           clear sky  2021-01-29 17:02:12
# 694          90        7.00     overcast clouds  2021-01-29 17:02:12
# 695          55        9.42       broken clouds  2021-01-29 17:02:12
# 696           0       23.02           clear sky  2021-01-29 16:57:56
#
# [697 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
